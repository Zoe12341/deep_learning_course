# %%
import tensorflow as tf
import timeit
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789001604.759764  136077 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dir(timeit)
# Out:
# ['Timer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_globals',
#  'default_number',
#  'default_repeat',
#  'default_timer',
#  'dummy_src_name',
#  'gc',
#  'itertools',
#  'main',
#  'reindent',
#  'repeat',
#  'sys',
#  'template',
#  'time',
#  'timeit']

# %% [markdown]
# ## check physical GPU availability

# %%
# returns whether TensorFlow was built with CUDA (GPU) support
tf.test.is_built_with_cuda()
# Out:
# True

# %%
# returns a list of available physical GPUs
tf.config.list_physical_devices("GPU")
# Out:
# E0000 00:00:1789001606.638742  136077 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# []

# %%
# returns the names of physical GPUs
tf.test.gpu_device_name()
# Out:
# ''

# %% [markdown]
# ## a test case

# %%
# initialize random matrices on CPU and GPU
with tf.device("/CPU:0"):
    cpu_m1 = tf.random.normal(shape=[10000, 1000])
    cpu_m2 = tf.random.normal(shape=[1000, 5000])
    print(cpu_m1.device, "\n", cpu_m2.device, "\n"*2)

with tf.device("/GPU:0"):
    gpu_m1 = tf.random.normal([10000, 1000])
    gpu_m2 = tf.random.normal([1000, 5000])
    print(gpu_m1.device, "\n", gpu_m2.device)
# Out:
# /job:localhost/replica:0/task:0/device:CPU:0
#  /job:localhost/replica:0/task:0/device:CPU:0
#
#
# /job:localhost/replica:0/task:0/device:CPU:0
#  /job:localhost/replica:0/task:0/device:CPU:0

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# perform matrix multiplication test
def cpu_test():
    with tf.device("/CPU:0"):
        res = tf.matmul(cpu_m1, cpu_m2)
    return res

def gpu_test():
    with tf.device("/GPU:0"):
        res = tf.matmul(gpu_m1, gpu_m2)
    return res

if __name__ == "__main__":
    cpu_time = timeit.timeit(cpu_test, number=50)
    gpu_time = timeit.timeit(gpu_test, number=50)
    print(f"CPU run time: {cpu_time}\nGPU run time: {gpu_time}")
# Out:
# CPU run time: 7.5296165709996785
# GPU run time: 8.096923824000442
